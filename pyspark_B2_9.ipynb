# %%
joins in spark:-
===============
left   ===>
inner ===>
outer ===>

left anti   ===> 

left  right
1      1
2      5
3      6

# %%
emp_df   ===> dept_id
dept_df  ===> dept_id

Ashok  IT dept
Naveen Finance dept


emp_df1 = emp_df.join(dept_df, emp_df.dep_id = dept_df.id, 'left')


joins are wide transformation =====> Data suffling ===> 

BoradCast join =====> 

DEPT ===> BoradCast  ===>  one copy will get stored in all exectors 

Spark 3.x ===> physical plan ===> 

BoardCast ===> 10mb

# %%
Catalyst optimizer:-
==================

# %%
what are the joins in spark
what are the join stratergies in spark
what is boardcast join
what is boradcast variables and acumalators in spark
What is catalyst optimizer and explain how it opgtimizes the code
How left anti join works in spark
What is predicate pushdown
What is delta file format
