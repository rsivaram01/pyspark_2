# %%
file based ===> csv file ===> read ===> transformation ==> then we are writing some where

ApI based consumption ======> 


Data base ====> API ====> user 


windy.com ===> Rest API (keys) ===> we will the api and then we will get the data  


postman ===> we can test the api connection


API ===> it will response ==> responce code (200 - success), ( failure 400, 500 ) 

Data ===> json format

# %%
API ===> consume ===> json ===> we need faltten the json data ===>  landing_zone 

landingTable ===> Transfromation =====>   Curated_zone

# %%
python

requests ===> api connections

# %%
import requests

url = "https://api.open-meteo.com/v1/forecast?latitude=17.38&longitude=78.48&current_weather=true"
response = requests.get(url)
data = response.json()
status = response.status_code
if status == 200:
    df = spark.createDataFrame(data)

# %%
df = spark.createDataFrame([data])

# %%
df.withColumn('current_weather_windspeed', df['current_weather']['windspeed']).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
status = response.status_code

# %%
status
# Out:
# 200

# %%
data
# Out:
# {'latitude': 17.375,
#  'longitude': 78.5,
#  'generationtime_ms': 0.07462501525878906,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 498.0,
#  'current_weather_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature': '°C',
#   'windspeed': 'km/h',
#   'winddirection': '°',
#   'is_day': '',
#   'weathercode': 'wmo code'},
#  'current_weather': {'time': '2026-02-06T14:00',
#   'interval': 900,
#   'temperature': 23.3,
#   'windspeed': 6.1,
#   'winddirection': 118,
#   'is_day': 0,
#   'weathercode': 2}}
