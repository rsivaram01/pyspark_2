# %%
emp_df = spark.read.options(header='true',inferSchema = True).csv("/Volumes/sample_cat/default/volume_csv/emp_dataset/employees.csv")

# %%
from pyspark.sql.functions import when

emp1 = emp_df.withColumn(
    "Dept_name",
    when(emp_df.DEPARTMENT_ID == 10, 'TECH')
    .when(emp_df.DEPARTMENT_ID == 20, 'Oops')
    .otherwise("Unknown")
)

# %%
emp1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df.select("DEPARTMENT_ID").distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEPARTMENT_ID</th></tr></thead><tbody><tr><td>20</td></tr><tr><td>30</td></tr><tr><td>60</td></tr><tr><td>50</td></tr><tr><td>40</td></tr><tr><td>110</td></tr><tr><td>100</td></tr><tr><td>70</td></tr><tr><td>90</td></tr><tr><td>10</td></tr></tbody></table></div>

# %%
dept wise ==> i want to max, min, avg salary

# %%
from pyspark.sql.functions import *

# %%
# agg

emp1.groupBy("DEPARTMENT_ID").agg(max("SALARY"),min('SALARY'),sum('SALARY')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Window functions:-
===================

row_number()
rank()
dense_rank()
lead()
lag()

# %%
# Surrogate Key  ===> nothing but sequence id or num

1. row_number()
2. monotonically_increasing_id()
3. sh1, sh2, sh3

# %%
from pyspark.sql.window import Window

win = Window.partitionBy(lit('')).orderBy(lit(''))

emp2 = emp1.withColumn('rnum',row_number().over(win))

# %%
emp2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp2.withColumn("m_id", monotonically_increasing_id() + 1).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import *

# %%
d_win = Window.partitionBy("DEPARTMENT_ID").orderBy(col("SALARY").desc())

# %%
emp3 = emp2.withColumn("d_rank", dense_rank().over(d_win))

# %%
emp3.filter(col("d_rank") == 1).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
1. What are all the window fucntions you know?
2. What is surrogate key, where we need to use
3. when you use row_number() when you will use rank() or dense_rank() ==> give me example for each case
