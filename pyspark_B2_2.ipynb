# %%
emp_df1 = spark.read.options(header='true', inferSchema='true').csv("/Volumes/sample_cat/default/volume_csv/emp_dataset/employees.csv")

# %%
emp_df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df2 = emp_df1.union(emp_df1)

# %%
emp_df2.count()
# Out:
# 100

# %%
emp_df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dedup_emp2 = emp_df2.dropDuplicates()

# %%
dedup_emp2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df1.count()
# Out:
# 50

# %%
# I want to remove duplicates 

dedup_emp = emp_df1.dropDuplicates()

# %%
dedup_emp.count()
# Out:
# 50

# %%
emp_df1.dropDuplicates(["EMPLOYEE_ID","FIRST_NAME"]).display()

# daily ===> sql server ( updated, inserts, delets ) ===> CDC ==> Change data capture
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# withColumn()

isnull_df = emp_df1.withColumn("Isnull", emp_df1['MANAGER_ID'].isNull())

isnull_df1 = isnull_df.withColumn("IsNotnull", emp_df1['MANAGER_ID'].isNotNull())

isnull_df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df1.distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df2.count()
# Out:
# 100

# %%
emp_df2.distinct().count()
# Out:
# 50

# %%
# how to cache data

emp_df2.cache()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8379623711455617>, line 3
#       1 # how to cache data
# ----> 3 emp_df2.cache()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:2126, in DataFrame.cache(self)
#    2125 def cache(self) -> ParentDataFrame:
# -> 2126     return self.persist()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:2133, in DataFrame.persist(self, storageLevel)
#    2128 def persist(
#    2129     self,
#    2130     storageLevel: StorageLevel = (StorageLevel.MEMORY_AND_DISK_DESER),
#    2131 ) -> ParentDataFrame:
#    2132     relation = self._plan.plan(self._session.client)
# -> 2133     self._session.client._analyze(
#    2134         method="persist", relation=relation, storage_level=storageLevel
#    2135     )
#    2136     return self
#
# ...

# %%
emp_df2.persist()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8379623711455618>, line 1
# ----> 1 emp_df2.persist()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:2133, in DataFrame.persist(self, storageLevel)
#    2128 def persist(
#    2129     self,
#    2130     storageLevel: StorageLevel = (StorageLevel.MEMORY_AND_DISK_DESER),
#    2131 ) -> ParentDataFrame:
#    2132     relation = self._plan.plan(self._session.client)
# -> 2133     self._session.client._analyze(
#    2134         method="persist", relation=relation, storage_level=storageLevel
#    2135     )
#    2136     return self
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1859, in SparkConnectClient._analyze(self, method, **kwargs)
#    1857     raise SparkConnectException("Invalid state during retry exception handling.")
# ...

# %%
emp_df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# temp table

emp_df2.createOrReplaceTempView("emp_temp")

# %%
sql_emp_df = spark.sql("select * from emp_temp where EMPLOYEE_ID = 100")

# %%
sql_emp_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EMPLOYEE_ID</th><th>FIRST_NAME</th><th>LAST_NAME</th><th>EMAIL</th><th>PHONE_NUMBER</th><th>HIRE_DATE</th><th>JOB_ID</th><th>SALARY</th><th>COMMISSION_PCT</th><th>MANAGER_ID</th><th>DEPARTMENT_ID</th></tr></thead><tbody><tr><td>100</td><td>Steven</td><td>King</td><td>SKING</td><td>515.123.4567</td><td>17-JUN-03</td><td>AD_PRES</td><td>24000</td><td> - </td><td> - </td><td>90</td></tr><tr><td>100</td><td>Steven</td><td>King</td><td>SKING</td><td>515.123.4567</td><td>17-JUN-03</td><td>AD_PRES</td><td>24000</td><td> - </td><td> - </td><td>90</td></tr></tbody></table></div>

# %%
# %sql

select * from emp_temp where EMPLOYEE_ID = 100
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EMPLOYEE_ID</th><th>FIRST_NAME</th><th>LAST_NAME</th><th>EMAIL</th><th>PHONE_NUMBER</th><th>HIRE_DATE</th><th>JOB_ID</th><th>SALARY</th><th>COMMISSION_PCT</th><th>MANAGER_ID</th><th>DEPARTMENT_ID</th></tr></thead><tbody><tr><td>100</td><td>Steven</td><td>King</td><td>SKING</td><td>515.123.4567</td><td>17-JUN-03</td><td>AD_PRES</td><td>24000</td><td> - </td><td> - </td><td>90</td></tr><tr><td>100</td><td>Steven</td><td>King</td><td>SKING</td><td>515.123.4567</td><td>17-JUN-03</td><td>AD_PRES</td><td>24000</td><td> - </td><td> - </td><td>90</td></tr></tbody></table></div>

# %%
1. read a emp csv file , put in one dataframe
2. filter employees having saalry> 10000 and their hiring month should be in JUNE
3. empid, full_name

full_name = FIRST_NAME + onspace + LAST_NAME

example :- 'Steven King'
