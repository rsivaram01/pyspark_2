# %%
Actions and Trasnformations

1. lazy evalution
2. DAG  ==============> tmrw 
3. Lineage
4. Cache
5. Persist

# %%
input_Data
sno,   name
1  ,   aa


sno,   name,  dummy_col
1  ,   Aa,      


Action:-
======
when we apply action on data, it will return something on console

# %%
spark

# %%
csv
json
tsv
tab delimeter

# %%
/Volumes/sample_cat/default/volume_csv/sample_dir/atc_pre_departure_delays_2016.csv

# %%
l = 34

# %%
l
# Out:
# 34

# %%
df = spark.read.csv("/Volumes/sample_cat/default/volume_csv/sample_dir/atc_pre_departure_delays_2016.csv")

# %%
from pyspark.sql.functions import *

df1 = df.withColumn("dummy_col", lit(''))

# %%
csv file  ==> df ===> df1  ==> df2  ===>df4  


df2.cache() ===> df4

df2  ===> i'll store it in memory 

df2.cache()


df4.count()
df2.count()

df1.display() or df1.count()


i want to cache 5gb data, but i have 3gb memory 

df.persist()

3gb ===> fit, 2gb ==> it will spill on disk

# %%
# lineage ====> backtrack of your all transformation you applied

# %%
df1.count()
# Out:
# 96598

# %%
read from page num 45 to 58 


1. what is sparksession
2. what is dataframe
3. what is lazy eavolution in spark
5. what is the diffrence between cache and persist
6. what are actions and transformation
7. what is lineage in spark 
8. how to read csv file in pyspark
