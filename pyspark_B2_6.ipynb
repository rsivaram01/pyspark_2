# %%
emp_df = spark.read.options(header='true').csv("/Volumes/sample_cat/default/volume_csv/emp_dataset/employees.csv")

# %%
emp_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df.printSchema()
# Out:
# root
#  |-- EMPLOYEE_ID: string (nullable = true)
#  |-- FIRST_NAME: string (nullable = true)
#  |-- LAST_NAME: string (nullable = true)
#  |-- EMAIL: string (nullable = true)
#  |-- PHONE_NUMBER: string (nullable = true)
#  |-- HIRE_DATE: string (nullable = true)
#  |-- JOB_ID: string (nullable = true)
#  |-- SALARY: string (nullable = true)
#  |-- COMMISSION_PCT: string (nullable = true)
#  |-- MANAGER_ID: string (nullable = true)
#  |-- DEPARTMENT_ID: string (nullable = true)

# %%
emp_df.schema
# Out:
# StructType([StructField('EMPLOYEE_ID', StringType(), True), StructField('FIRST_NAME', StringType(), True), StructField('LAST_NAME', StringType(), True), StructField('EMAIL', StringType(), True), StructField('PHONE_NUMBER', StringType(), True), StructField('HIRE_DATE', StringType(), True), StructField('JOB_ID', StringType(), True), StructField('SALARY', StringType(), True), StructField('COMMISSION_PCT', StringType(), True), StructField('MANAGER_ID', StringType(), True), StructField('DEPARTMENT_ID', StringType(), True)])

# %%
StructType([StructField('EMPLOYEE_ID', StringType(), True), StructField('FIRST_NAME', StringType(), True), StructField('LAST_NAME', StringType(), True), StructField('EMAIL', StringType(), True), StructField('PHONE_NUMBER', StringType(), True), StructField('HIRE_DATE', StringType(), True), StructField('JOB_ID', StringType(), True), StructField('SALARY', StringType(), True), StructField('COMMISSION_PCT', StringType(), True), StructField('MANAGER_ID', StringType(), True), StructField('DEPARTMENT_ID', StringType(), True)])

# %%
StructType([StructField("emp_id",InetgerType(), True), StructField("name",StringType(), True)])

# %%
# how to define a schema for dataset

# %%
from pyspark.sql.types import *

emp_sch = StructType([StructField("EMPLOYEE_ID",IntegerType(), True), StructField("FIRST_NAME",StringType(), True)])

# %%
df = spark.read.options(header=True).schema(emp_sch).csv("/Volumes/sample_cat/default/volume_csv/emp_sc_set/employees (1).csv")

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- EMPLOYEE_ID: integer (nullable = true)
#  |-- FIRST_NAME: string (nullable = true)

# %%
ss = df.schema

# %%
ss
# Out:
# StructType([StructField('EMPLOYEE_ID', IntegerType(), True), StructField('FIRST_NAME', StringType(), True)])

# %%
cols = df.columns

# %%
from pyspark.sql.functions import *

# %%
cols = df.columns
if 'SALARY' not in cols:
    df1 = df.withColumn("SALARY",lit(10))

# %%
col1 = df1.columns

# %%
col1
# Out:
# ['EMPLOYEE_ID', 'FIRST_NAME', 'SALARY']

# %%
l_col1 = [i.lower() for i in col1]

# %%
l_col1
# Out:
# ['employee_id', 'first_name', 'salary']

# %%
df1.printSchema()
# Out:
# root
#  |-- EMPLOYEE_ID: integer (nullable = true)
#  |-- FIRST_NAME: string (nullable = true)
#  |-- SALARY: integer (nullable = false)

# %%
df1 = df1.toDF(*l_col1)

# %%
df1.printSchema()
# Out:
# root
#  |-- employee_id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- salary: integer (nullable = false)

# %%
emp ===> read 
Schema
