# %%
pyspark

numpy
pandas
matplotlib

# %%
pyspark :- pyspark is lib to intract with spark

# %%
data will be many forms:-
=======================
file form   ( csv, json, xml, pdf,word)
table form  (mysql, posgress, nosql, hive)
api consumption (rest api)

# %%
# how to read csv file  

1. file  ===> certain path

# %%
from pyspark.sql.sparksession import SparkSession

spark = SparkSession.builder.appName("dummy_app1").getOrCreate()

# %%
emp_df = spark.read.csv("/Volumes/sample_cat/default/volume_csv/emp_dataset/employees.csv")

# %%
# column names are not coming properrly
# Data types also not coming properly

# %%
emp_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df1 = spark.read.options(header='true', inferSchema='true').csv("/Volumes/sample_cat/default/volume_csv/emp_dataset/employees.csv")

# %%
emp_df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df3 = emp_df1.select("eMPLOYEE_ID","SALARY")

# %%
emp_df1.select(emp_df1.EMPLOYEE_ID,emp_df1.SALARY).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df1.select(emp_df1['EMPLOYEE_ID'],emp_df1['SALARY']).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_df3.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_sal_data = emp_df1.filter(emp_df1.SALARY >= 10000).select("EMPLOYEE_ID",'FIRST_NAME','LAST_NAME')

# %%
emp_sal_data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EMPLOYEE_ID</th><th>FIRST_NAME</th><th>LAST_NAME</th></tr></thead><tbody><tr><td>201</td><td>Michael</td><td>Hartstein</td></tr><tr><td>204</td><td>Hermann</td><td>Baer</td></tr><tr><td>205</td><td>Shelley</td><td>Higgins</td></tr><tr><td>100</td><td>Steven</td><td>King</td></tr><tr><td>101</td><td>Neena</td><td>Kochhar</td></tr><tr><td>102</td><td>Lex</td><td>De Haan</td></tr><tr><td>108</td><td>Nancy</td><td>Greenberg</td></tr><tr><td>114</td><td>Den</td><td>Raphaely</td></tr></tbody></table></div>

# %%
emp_sal_data.show()
# Out:
# +-----------+----------+---------+
# |EMPLOYEE_ID|FIRST_NAME|LAST_NAME|
# +-----------+----------+---------+
# |        201|   Michael|Hartstein|
# |        204|   Hermann|     Baer|
# |        205|   Shelley|  Higgins|
# |        100|    Steven|     King|
# |        101|     Neena|  Kochhar|
# |        102|       Lex|  De Haan|
# |        108|     Nancy|Greenberg|
# |        114|       Den| Raphaely|
# +-----------+----------+---------+

# %%
# read a csv file in pyspark
# start with impotimg sprksession and create spark instance 

from pyspark.sql.sparksession import SparkSession

spark = SparkSession.builder.appName("dummy_app1").getOrCreate()

emp_df1 = spark.read.options(header='true', inferSchema='true').csv("/Volumes/sample_cat/default/volume_csv/emp_dataset/employees.csv")

# %%
questions:-

1.
# read a csv file in pyspark
# start with impotimg sprksession and create spark instance 

2. how to define a schema in pyspark for a dataframe
