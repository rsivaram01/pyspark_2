# %%
id	agent	agent_type	agent_name
1	spar	0	gs shipping
1	spar	1	chennai shipping
2	gemini		chennai shipping
2	gemini		
3	apus	1	sng shipping



As it is ===> consume ===> table (landing_zone.vessel.agent_details)


read the table using pyspark ===> df = spark.table("landing_zone.vessel.agent_details") 


id	agent_details
1	spar : owners - gs shipping | charters - chennai shipping
2	gemini : - chennai shipping |
3	apus : charters - sng shipping

===> after transforming data like above load in another table (curated_zone.vessel.agent_details)
